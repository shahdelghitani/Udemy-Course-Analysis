# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\skynet\AppData\Local\Programs\Python\Python312\python.exe: No module named pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"c:\Users\skynet\Downloads\udemy_courses_clean.csv")
data.sample(10)
# Out:
#       Unnamed: 0  course_id  \
# 3051        3051     180547
# 2955        2955     834600
# 2512        2512    1002030
# 2680        2680     922600
# 2569        2569     641868
# 676          676     212952
# 211          211     692176
# 2718        2718    1169378
# 2676        2676     856490
# 2159        2159     374566
#
#                                            course_title  \
# 3051         PHP Development with the Laravel Framework
# 2955  The Web Developers Guide: Learn HTML & CSS Fun...
# 2512  Web Development w/ Google’s Go (golang) Progra...
# 2680                   CSS Web Development Crash Course
# 2569  The Docker for DevOps course: From development...
# 676                              ビットコイン生態系｜既存通貨が主役をやめる日
# 211   Apply finance concepts for smart project manag...
# 2718  Build a complete Fiverr clone with Node + Algo...
# 2676   Interaction Design Specialist For Web Developers
# 2159  Learn to Play Percussion: Beginner to Pro made...
#
# ...

# %% [markdown]
# ## subject

# %%
data['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     681
# Graphic Design          603
# Name: count, dtype: int64

# %%
data['subject'].value_counts().plot(kind='bar')
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Web Development'),
#   Text(1, 0, 'Business Finance'),
#   Text(2, 0, 'Musical Instruments'),
#   Text(3, 0, 'Graphic Design')])

# %%
data['subject'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['subject'].value_counts())
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Web Development'),
#   Text(1, 0, 'Business Finance'),
#   Text(2, 0, 'Musical Instruments'),
#   Text(3, 0, 'Graphic Design')])

# %% [markdown]
# ## num_of_subscribers

# %%
data.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1870747
# Graphic Design         1063148
# Musical Instruments     846719
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
data['num_subscribers'].mean()
# Out:
# 3193.3711648112953

# %%
data['num_subscribers'].idxmax()
# Out:
# 2832

# %%
data.iloc[2832]
# Out:
# Unnamed: 0                                                          2832
# course_id                                                          41295
# course_title                        Learn HTML5 Programming From Scratch
# url                    https://www.udemy.com/learn-html5-programming-...
# is_paid                                                            False
# price                                                               Free
# num_subscribers                                                   268923
# num_reviews                                                         8629
# num_lectures                                                          45
# level                                                         All Levels
# content_duration                                              10.5 hours
# published_timestamp                                 2013-02-14T07:03:41Z
# subject                                                  Web Development
# ...

# %% [markdown]
# ## level

# %%
data['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level', '52'], dtype=object)

# %%
false_row =( data['level'] == '52')
data[false_row]
# Out:
#       Unnamed: 0  course_id  \
# 2066        2066      96698
#
#                                            course_title    url  \
# 2066  Learn Classical Guitar Technique and play 'Spa...  000!"
#
#                                           is_paid price  num_subscribers  \
# 2066  https://www.udemy.com/learnguitartoworship/  TRUE               30
#
#       num_reviews  num_lectures level content_duration published_timestamp  \
# 2066         1463            29    52   Beginner Level             3 hours
#
#                   subject                                 clean_course_title
# 2066  Musical Instruments  Learn Classical Guitar Technique play Spanish ...

# %%
data = data[data['level'] != 52]

# %%
data.groupby('level')['num_subscribers'].sum(
    
)
# Out:
# level
# 52                         30
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
data.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            699
#                      Beginner Level        341
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
#                      52                      1
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: count, dtype: int64

# %%
data.groupby('subject')['level'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='level' , y='num_subscribers' , data=data , hue ='subject')
plt.show()

# %% [markdown]
# # price

# %%
data['price'].dtype
# Out:
# dtype('O')

# %%
data['price'].unique()
# Out:
# array(['200', '75', '45', '95', '150', '65', '195', '30', '20', '50',
#        '175', '140', '115', '190', '125', '60', '145', '105', '155',
#        '185', '180', '120', '25', '160', '40', 'Free', '100', '90', '35',
#        '80', '70', '55', '165', '130', '85', '170', '110', '135', 'TRUE'],
#       dtype=object)

# %%
data['price'] =data['price'].str.replace('Free|TRUE' , '0'  , regex= True)

# %%
data['price'] = data['price'].astype(float)

# %%
data['price'].describe()
# Out:
# count    3683.000000
# mean       65.992398
# std        60.985586
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
data['price'].idxmax()
# Out:
# 0

# %%
data.groupby('subject')['price'].sum()
# Out:
# subject
# Business Finance       82040.0
# Graphic Design         34870.0
# Musical Instruments    33700.0
# Web Development        92440.0
# Name: price, dtype: float64

# %%
data.groupby('subject')['price'].sum().plot(kind='pie' , autopct='%1.1f%%' )
# Out:
# <Axes: ylabel='price'>

# %%
data['profit'] = data['price']*data['num_subscribers']

# %%
data['profit'].tolist()
# Out:
# [429400.0,
#  209400.0,
#  97830.0,
#  232845.0,
#  255200.0,
#  1383150.0,
#  100100.0,
#  277115.0,
#  1008540.0,
#  165400.0,
#  856800.0,
#  276000.0,
#  108210.0,
#  791895.0,
#  58800.0,
#  170700.0,
#  98380.0,
#  533200.0,
#  267700.0,
#  769025.0,
#  161800.0,
#  459000.0,
#  761175.0,
#  95800.0,
#  112815.0,
#  867900.0,
#  1066800.0,
#  700875.0,
#  431550.0,
#  143640.0,
#  110675.0,
#  368600.0,
#  395865.0,
#  206000.0,
#  208200.0,
#  1537380.0,
#  3295500.0,
#  2288200.0,
#  4340115.0,
#  1672125.0,
#  4773795.0,
#  743145.0,
#  973245.0,
#  861235.0,
#  4039000.0,
#  1506300.0,
#  34865.0,
#  2120600.0,
#  227430.0,
#  433950.0,
#  316000.0,
#  1007475.0,
#  374500.0,
#  186570.0,
#  222600.0,
#  498840.0,
#  1114400.0,
#  207785.0,
#  18720.0,
#  131600.0,
#  852705.0,
#  251220.0,
#  1463975.0,
#  651000.0,
#  1469085.0,
#  252000.0,
#  1818000.0,
#  631250.0,
#  462000.0,
#  1022680.0,
#  806375.0,
#  1177430.0,
#  358600.0,
#  64460.0,
#  983100.0,
#  297400.0,
# ...

# %% [markdown]
# ## is_paid

# %%
data
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True                                           2738
# TRUE                                            634
# False                                           264
# FALSE                                            46
# https://www.udemy.com/learnguitartoworship/       1
# Name: count, dtype: int64

# %%
paid = {'True' : True , 'TRUE' : True,  'False' : False , 'FALSE' : False  , 'https://www.udemy.com/learnguitartoworship/' :True}

# %%
data['is_paid'] = data['is_paid'].map(paid)

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3373
# False     310
# Name: count, dtype: int64

# %%
data['is_paid'].value_counts().plot(kind = 'pie' , autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data.groupby('subject')['is_paid'].value_counts()
# Out:
# subject              is_paid
# Business Finance     True       1103
#                      False        96
# Graphic Design       True        568
#                      False        35
# Musical Instruments  True        635
#                      False        46
# Web Development      True       1067
#                      False       133
# Name: count, dtype: int64

# %%
data.groupby('subject')['is_paid'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='subject,is_paid'>

# %%
data['clean_course_title'].str.len()
# Out:
# 0       34.0
# 1       49.0
# 2       48.0
# 3       43.0
# 4       32.0
#         ...
# 3678    47.0
# 3679    31.0
# 3680    19.0
# 3681    45.0
# 3682    39.0
# Name: clean_course_title, Length: 3683, dtype: float64

# %%
data['clean_course_title_len'] = data['clean_course_title'].str.len()

# %%
data
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
data['clean_course_title_len'].max()
# Out:
# 201.0

# %%
data['clean_course_title_len'].idxmax()
# Out:
# 2191

# %%
data.loc[2191]
# Out:
# Unnamed: 0                                                             2191
# course_id                                                            286898
# course_title              Aprende a tocar el Acordeón 'de oído y con téc...
# url                       https://www.udemy.com/aprende-los-secretos-de-...
# is_paid                                                                True
# price                                                                  75.0
# num_subscribers                                                         158
# num_reviews                                                              17
# num_lectures                                                             59
# level                                                            All Levels
# content_duration                                                  2.5 hours
# published_timestamp                                    2014-07-28T13:55:43Z
# ...

# %%
data['published_timestamp']
# Out:
# 0       2017-01-18T20:58:58Z
# 1       2017-03-09T16:34:20Z
# 2       2016-12-19T19:26:30Z
# 3       2017-05-30T20:07:24Z
# 4       2016-12-13T14:57:18Z
#                 ...
# 3678    2016-06-14T17:36:46Z
# 3679    2017-03-10T22:24:30Z
# 3680    2015-12-30T16:41:42Z
# 3681    2016-08-11T19:06:15Z
# 3682    2014-09-28T19:51:11Z
# Name: published_timestamp, Length: 3683, dtype: object

# %%
data['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3678    [2016-06-14, 17:36:46Z]
# 3679    [2017-03-10, 22:24:30Z]
# 3680    [2015-12-30, 16:41:42Z]
# 3681    [2016-08-11, 19:06:15Z]
# 3682    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3683, dtype: object

# %%
data['Date'] = data['published_timestamp'].str.split('T').str.get(0)
data
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
data['Time'] = data['published_timestamp'].str.slice(11,19)
data
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
data['Date'] = data['Date'].str.replace('3 hours' , '2015-01-16')

# %%
data['Date'] = pd.to_datetime(data['Date'] , format= '%Y-%m-%d')

# %%
data.dtypes
# Out:
# Unnamed: 0                         int64
# course_id                          int64
# course_title                      object
# url                               object
# is_paid                             bool
# price                            float64
# num_subscribers                    int64
# num_reviews                        int64
# num_lectures                       int64
# level                             object
# content_duration                  object
# published_timestamp               object
# subject                           object
# clean_course_title                object
# profit                           float64
# clean_course_title_len           float64
# Date                      datetime64[ns]
# Time                              object
# dtype: object

# %%
data['year'] = data['Date'].dt.year
data
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
data['Month'] = data['Date'].dt.month
data
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
data['year'].unique()
# Out:
# array([2017, 2016, 2014, 2015, 2013, 2012, 2011])

# %%
data.groupby('year')['num_subscribers'].sum()
# Out:
# year
# 2011     119028
# 2012     555339
# 2013    1723438
# 2014    1930406
# 2015    3475354
# 2016    2966644
# 2017     990977
# Name: num_subscribers, dtype: int64

# %%
data.groupby('year')['num_subscribers'].sum().plot(kind= 'bar')
# Out:
# <Axes: xlabel='year'>
